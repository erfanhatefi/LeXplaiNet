# %%
import torch
import torchvision
from lexplainet.explicit.rules import *
from lexplainet.explicit.torchvision import ResNet18_canonized

device = "cpu"

def model_loader_resnet18(device):
    model = torchvision.models.resnet18(pretrained=True)
    model = model.to(device)
    model.device = device
    model.eval()
    return model

def getmodel_lrpwrapped_res18_simple(loaded_model):
    composite = {    
        'ReLU':          {"rule": relu_wrapper_fct},
        'MaxPool2d': {"rule": maxpool2d_wrapper_fct},
        'SiLU':          {"rule": relu_wrapper_fct },  
        'BatchNorm2d':   {"rule": relu_wrapper_fct},
        'Conv2d':       {"rule": conv2d_gammalifted_wrapper_fct, "ignore_bias": True, "gamma": 1000, "eps": 1e-3, "beta": 2, "max_beta": 2}, #conv2d_betaadaptive_wrapper_fct,
        'Linear':        {"rule": linear_eps_wrapper_fct, "eps": 1e-3},  
        'AdaptiveAvgPool2d': {"rule": adaptiveavgpool2d_wrapper_fct, "eps": 1e-3},
        'ElementwiseSum': {"rule": eltwisesum_eps_wrapper_fct, "eps": 1e-3},
        }

    model = ResNet18_canonized(pretrained=False)
    model.copyfromresnet(loaded_model, composite=composite)

    model.eval()
    model.to(device)
    model.device = device
    
    return model

model = model_loader_resnet18(device)
modified_model = getmodel_lrpwrapped_res18_simple(model)
modified_model
# Out:
# at src_module_name
# at src_module_name conv1
# at src_module_name bn1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name relu
# at src_module_name maxpool
# at src_module_name layer1
# at src_module_name layer1.0
# at src_module_name layer1.0.conv1
# at src_module_name layer1.0.bn1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer1.0.relu
# at src_module_name layer1.0.conv2
# at src_module_name layer1.0.bn2
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer1.1
# at src_module_name layer1.1.conv1
# at src_module_name layer1.1.bn1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer1.1.relu
# at src_module_name layer1.1.conv2
# at src_module_name layer1.1.bn2
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer2
# at src_module_name layer2.0
# at src_module_name layer2.0.conv1
# at src_module_name layer2.0.bn1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer2.0.relu
# at src_module_name layer2.0.conv2
# at src_module_name layer2.0.bn2
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer2.0.downsample
# at src_module_name layer2.0.downsample.0
# at src_module_name layer2.0.downsample.1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer2.1
# at src_module_name layer2.1.conv1
# at src_module_name layer2.1.bn1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer2.1.relu
# at src_module_name layer2.1.conv2
# at src_module_name layer2.1.bn2
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer3
# at src_module_name layer3.0
# at src_module_name layer3.0.conv1
# at src_module_name layer3.0.bn1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer3.0.relu
# at src_module_name layer3.0.conv2
# at src_module_name layer3.0.bn2
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer3.0.downsample
# at src_module_name layer3.0.downsample.0
# at src_module_name layer3.0.downsample.1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer3.1
# at src_module_name layer3.1.conv1
# at src_module_name layer3.1.bn1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer3.1.relu
# at src_module_name layer3.1.conv2
# at src_module_name layer3.1.bn2
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer4
# at src_module_name layer4.0
# at src_module_name layer4.0.conv1
# at src_module_name layer4.0.bn1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer4.0.relu
# at src_module_name layer4.0.conv2
# at src_module_name layer4.0.bn2
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer4.0.downsample
# at src_module_name layer4.0.downsample.0
# at src_module_name layer4.0.downsample.1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer4.1
# at src_module_name layer4.1.conv1
# at src_module_name layer4.1.bn1
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name layer4.1.relu
# at src_module_name layer4.1.conv2
# at src_module_name layer4.1.bn2
# Wrap Conv2d
# Wrap BatchNorm2d
# at src_module_name avgpool
# at src_module_name fc
# Wrap Linear
# Wrap ReLU
# Wrap MaxPool2d
# Wrap ReLU
# Wrap ElementwiseSum
# Wrap ReLU
# Wrap ElementwiseSum
# Wrap ReLU
# Wrap ElementwiseSum
# Wrap ReLU
# Wrap ElementwiseSum
# Wrap ReLU
# Wrap ElementwiseSum
# Wrap ReLU
# Wrap ElementwiseSum
# Wrap ReLU
# Wrap ElementwiseSum
# Wrap ReLU
# Wrap ElementwiseSum
# Wrap AdaptiveAvgPool2d
# Not updated:
# Not updated: conv1.module
# Not updated: bn1.module
# Not updated: relu.module
# Not updated: maxpool.module
# Not updated: layer1
# Not updated: layer1.0
# Not updated: layer1.0.conv1.module
# Not updated: layer1.0.bn1.module
# Not updated: layer1.0.relu.module
# Not updated: layer1.0.conv2.module
# Not updated: layer1.0.bn2.module
# Not updated: layer1.0.elementwise_sum.module
# Not updated: layer1.1
# Not updated: layer1.1.conv1.module
# Not updated: layer1.1.bn1.module
# Not updated: layer1.1.relu.module
# Not updated: layer1.1.conv2.module
# Not updated: layer1.1.bn2.module
# Not updated: layer1.1.elementwise_sum.module
# Not updated: layer2
# Not updated: layer2.0
# Not updated: layer2.0.conv1.module
# Not updated: layer2.0.bn1.module
# Not updated: layer2.0.relu.module
# Not updated: layer2.0.conv2.module
# Not updated: layer2.0.bn2.module
# Not updated: layer2.0.downsample
# Not updated: layer2.0.downsample.0.module
# Not updated: layer2.0.downsample.1.module
# Not updated: layer2.0.elementwise_sum.module
# Not updated: layer2.1
# Not updated: layer2.1.conv1.module
# Not updated: layer2.1.bn1.module
# Not updated: layer2.1.relu.module
# Not updated: layer2.1.conv2.module
# Not updated: layer2.1.bn2.module
# Not updated: layer2.1.elementwise_sum.module
# Not updated: layer3
# Not updated: layer3.0
# Not updated: layer3.0.conv1.module
# Not updated: layer3.0.bn1.module
# Not updated: layer3.0.relu.module
# Not updated: layer3.0.conv2.module
# Not updated: layer3.0.bn2.module
# Not updated: layer3.0.downsample
# Not updated: layer3.0.downsample.0.module
# Not updated: layer3.0.downsample.1.module
# Not updated: layer3.0.elementwise_sum.module
# Not updated: layer3.1
# Not updated: layer3.1.conv1.module
# Not updated: layer3.1.bn1.module
# Not updated: layer3.1.relu.module
# Not updated: layer3.1.conv2.module
# Not updated: layer3.1.bn2.module
# Not updated: layer3.1.elementwise_sum.module
# Not updated: layer4
# Not updated: layer4.0
# Not updated: layer4.0.conv1.module
# Not updated: layer4.0.bn1.module
# Not updated: layer4.0.relu.module
# Not updated: layer4.0.conv2.module
# Not updated: layer4.0.bn2.module
# Not updated: layer4.0.downsample
# Not updated: layer4.0.downsample.0.module
# Not updated: layer4.0.downsample.1.module
# Not updated: layer4.0.elementwise_sum.module
# Not updated: layer4.1
# Not updated: layer4.1.conv1.module
# Not updated: layer4.1.bn1.module
# Not updated: layer4.1.relu.module
# Not updated: layer4.1.conv2.module
# Not updated: layer4.1.bn2.module
# Not updated: layer4.1.elementwise_sum.module
# Not updated: avgpool.module
# Not updated: fc.module
# /home/erfan/miniconda3/envs/lrp_exercise/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/erfan/miniconda3/envs/lrp_exercise/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet_canonized(
#   (conv1): LRPRuleWrapper(
#     (module): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   )
#   (bn1): LRPRuleWrapper(
#     (module): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (relu): LRPRuleWrapper(
#     (module): ReLU(inplace=True)
#   )
#   (maxpool): LRPRuleWrapper(
#     (module): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): BasicBlockFused(
#       (conv1): LRPRuleWrapper(
#         (module): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn1): LRPRuleWrapper(
#         (module): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LRPRuleWrapper(
#         (module): ReLU(inplace=True)
#       )
#       (conv2): LRPRuleWrapper(
#         (module): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn2): LRPRuleWrapper(
#         (module): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (elementwise_sum): LRPRuleWrapper(
#         (module): ElementwiseSum()
#       )
#     )
#     (1): BasicBlockFused(
#       (conv1): LRPRuleWrapper(
#         (module): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn1): LRPRuleWrapper(
#         (module): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LRPRuleWrapper(
#         (module): ReLU(inplace=True)
#       )
#       (conv2): LRPRuleWrapper(
#         (module): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn2): LRPRuleWrapper(
#         (module): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (elementwise_sum): LRPRuleWrapper(
#         (module): ElementwiseSum()
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlockFused(
#       (conv1): LRPRuleWrapper(
#         (module): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (bn1): LRPRuleWrapper(
#         (module): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LRPRuleWrapper(
#         (module): ReLU(inplace=True)
#       )
#       (conv2): LRPRuleWrapper(
#         (module): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn2): LRPRuleWrapper(
#         (module): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Sequential(
#         (0): LRPRuleWrapper(
#           (module): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (1): LRPRuleWrapper(
#           (module): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (elementwise_sum): LRPRuleWrapper(
#         (module): ElementwiseSum()
#       )
#     )
#     (1): BasicBlockFused(
#       (conv1): LRPRuleWrapper(
#         (module): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn1): LRPRuleWrapper(
#         (module): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LRPRuleWrapper(
#         (module): ReLU(inplace=True)
#       )
#       (conv2): LRPRuleWrapper(
#         (module): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn2): LRPRuleWrapper(
#         (module): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (elementwise_sum): LRPRuleWrapper(
#         (module): ElementwiseSum()
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlockFused(
#       (conv1): LRPRuleWrapper(
#         (module): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (bn1): LRPRuleWrapper(
#         (module): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LRPRuleWrapper(
#         (module): ReLU(inplace=True)
#       )
#       (conv2): LRPRuleWrapper(
#         (module): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn2): LRPRuleWrapper(
#         (module): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Sequential(
#         (0): LRPRuleWrapper(
#           (module): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (1): LRPRuleWrapper(
#           (module): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (elementwise_sum): LRPRuleWrapper(
#         (module): ElementwiseSum()
#       )
#     )
#     (1): BasicBlockFused(
#       (conv1): LRPRuleWrapper(
#         (module): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn1): LRPRuleWrapper(
#         (module): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LRPRuleWrapper(
#         (module): ReLU(inplace=True)
#       )
#       (conv2): LRPRuleWrapper(
#         (module): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn2): LRPRuleWrapper(
#         (module): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (elementwise_sum): LRPRuleWrapper(
#         (module): ElementwiseSum()
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlockFused(
#       (conv1): LRPRuleWrapper(
#         (module): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#       (bn1): LRPRuleWrapper(
#         (module): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LRPRuleWrapper(
#         (module): ReLU(inplace=True)
#       )
#       (conv2): LRPRuleWrapper(
#         (module): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn2): LRPRuleWrapper(
#         (module): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Sequential(
#         (0): LRPRuleWrapper(
#           (module): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (1): LRPRuleWrapper(
#           (module): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (elementwise_sum): LRPRuleWrapper(
#         (module): ElementwiseSum()
#       )
#     )
#     (1): BasicBlockFused(
#       (conv1): LRPRuleWrapper(
#         (module): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn1): LRPRuleWrapper(
#         (module): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LRPRuleWrapper(
#         (module): ReLU(inplace=True)
#       )
#       (conv2): LRPRuleWrapper(
#         (module): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (bn2): LRPRuleWrapper(
#         (module): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (elementwise_sum): LRPRuleWrapper(
#         (module): ElementwiseSum()
#       )
#     )
#   )
#   (avgpool): LRPRuleWrapper(
#     (module): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (fc): LRPRuleWrapper(
#     (module): Linear(in_features=512, out_features=1000, bias=True)
#   )
# )

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from imagenet import IMAGENET_CLASS_NAMES
from imagenet.utils import inference_transform
from lexplainet.heatmap import show_image, load_image, plot_heatmap

from model_utils.inference import inference
from model_utils.autograd import explain_model_prediction

# %%
image_tensor = load_image('./dog_1.png', transform=inference_transform, device=device)
show_image(image_tensor, transform=inference_transform)
# Out:
# Image Tensor Shape: torch.Size([1, 3, 224, 224])

# %%
inference(modified_model, image_tensor, class_names=IMAGENET_CLASS_NAMES)

normalized_relevance, _ = explain_model_prediction(modified_model, image_tensor)

plot_heatmap(normalized_relevance)
# Out:
# Predicted Class: golden retriever, (Index: 207)

# %%
image_tensor = load_image('./dog_2.png', transform=inference_transform, device=device)
show_image(image_tensor, transform=inference_transform)
# Out:
# Image Tensor Shape: torch.Size([1, 3, 224, 224])

# %%
inference(modified_model, image_tensor, class_names=IMAGENET_CLASS_NAMES)

normalized_relevance, _ = explain_model_prediction(modified_model, image_tensor)

plot_heatmap(normalized_relevance)
# Out:
# Predicted Class: Pembroke, Pembroke Welsh corgi, (Index: 263)
